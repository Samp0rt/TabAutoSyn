# %%
import pandas as pd
from gen.gen import GAConfig, GeneticAlgorithm

# %%
df_train=pd.read_csv('examples/data/syn_iris.csv')
df_test=pd.read_csv('examples/data/real_iris.csv')

# %%
config = GAConfig(n_generations=20, crossover_prob=0.6,bootstrap_sample_ratio=0.9)
ga = GeneticAlgorithm(config=config,target_col='Species')
results = ga.run(df_train, df_test)
# Out:
# Gen 1: max=1.9911 avg=1.9600
# Gen 2: max=1.9925 avg=1.9703
# Gen 3: max=1.9925 avg=1.9782
# Gen 4: max=1.9919 avg=1.9851
# Gen 5: max=1.9934 avg=1.9846
# Gen 6: max=1.9934 avg=1.9822
# Gen 7: max=1.9926 avg=1.9810
# Gen 8: max=1.9926 avg=1.9862
# Gen 9: max=1.9926 avg=1.9836
# Gen 10: max=1.9925 avg=1.9860
# Gen 11: max=1.9929 avg=1.9888
# Gen 12: max=1.9934 avg=1.9879
# Gen 13: max=1.9934 avg=1.9869
# Gen 14: max=1.9934 avg=1.9910
# Gen 15: max=1.9934 avg=1.9896
# Gen 16: max=1.9934 avg=1.9883
# Gen 17: max=1.9935 avg=1.9864
# Gen 18: max=1.9935 avg=1.9856
# Gen 19: max=1.9937 avg=1.9888
# Gen 20: max=1.9935 avg=1.9867

# %%
ga.plot_history()
